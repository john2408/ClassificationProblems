# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')

from datetime import datetime
from os import getcwd
from os.path import join

from sklearn.metrics import accuracy_score, confusion_matrix

from sys import path
path.append( join( getcwd(), 'functions' ) )

from functions import preprocessing, modelling, postprocessing

# %% [markdown]
# ## 0. Parameters

# %%
current_time = datetime.now().strftime("%d-%m-%Y_%H_%M_%S")

sent_tokenizer = False # TODO: Adjust for input to CNN

# Text Cleaning Options
use_nltk_cleaning = False
text_cleaning = True

# Word Tokenizer Options
use_tfidf_tokenizer = False # TODO: Adjust for input to CNN
use_keras_tokenizer = True

# If set to FALSE then keras embedding space training is used instead
# Embedding Space possibilites are GloVe or TFIDF
use_pretrained_embeddings = True

# Only if use_pretrained_embeddings == True then select embedding vector space type
use_glove_pretrained_embeddings_weights = True
use_tfidf_as_embedding_weights = False

# Dictionary which will cotain all the model's variables
data = {}

# Initialize Model
data['epochs'] = 30 # NO. of optimizatoin runs
data['batch_size'] = 16 # No. of sentences batch to train
data['num_words'] = 5000 # No. of words to use in the embedding space of GloVe or TFIDF
data['cv'] = 4 # No. of Cross Validations
data['n_iter'] = 5 # No. of Iterations
data['seq_input_len'] = 40 # Length of the vector sentence ( no. of words per sentence)
data['embedding_dim'] = 40 # Length of the word vector ( dimension in the embedding space)
data['nodes_hidden_dense_layer'] = 5 # No. of nodes for hidden Dense layer


data['filepath'] = 'D:/Semillero Data Science/Deep Learning/pre-trained Word Embeddings/GloVe/glove.6B.50d.txt' # File path to GLoVe pretrained embedding words
data['output_file'] = f"results/{current_time}_Result.txt" # Name of output result file

# %%
param_grid = dict(num_filters_cv = [(64,16), (64,32), (128,16), (128,32), (256,64), (256,32), (256,64), (512,128), (512, 32)], # No of filter to use in convolution
                  kernel_size_cv = [(2,3), (2,4), (3,4), (3,5)], # No of words to check per Convolution 
                  vocab_size = [3000, 4000, 5000, 6000], # Vocab size if keras embedding space training is wanted
                  embedding_dim = [20, 30, 40, 50], 
                  seq_input_len = [50, 40, 30, 20, 10], 
                  nodes_hidden_dense_layer = [5, 10, 15, 20, 40],
                  use_pretrained_embeddings = [True, False])

# %%
# Small Test
# param_grid = dict(num_filters_cv = [(64,16)],
#                   kernel_size_cv = [(2,3)],
#                   vocab_size = [5000], 
#                   embedding_dim = [50],
#                   seq_input_len = [50], 
#                   nodes_hidden_dense_layer = [5],
#                   use_pretrained_embeddings = [True])

# %% [markdown]
# ## 1. Ingest Data

# %%
data_dir = 'D:/Data_Science/ClassificationProblems/Sentiment_Analysis/data/SA_4_Categories.csv'
corpus = pd.read_csv(data_dir ,encoding='latin-1', sep = ';')

# %%
corpus = preprocessing.data_cleaning(corpus = corpus,
                       sent_tokenizer = False, 
                       text_cleaning = True, 
                       use_nltk_cleaning = False)

# %%
corpus.head()
# Out:
#                                                 text  label
# 0  stable way business life many corporate purcha...      0
# 1  dozens companies already learned supply demand...      0
# 2  capabilities profitable international business...      0
# 3    almost every kind manufacturer answer questions      0
# 4      companies already responded growing pressures      0

# %% [markdown]
# ## 2. Preprocess Data

# %%
model_data = preprocessing.prepare_training_data(corpus)

# Concat two dictionaries
data = {**data, **model_data}

# %%
data.keys()
# Out:
# dict_keys(['epochs', 'batch_size', 'num_words', 'cv', 'n_iter', 'seq_input_len', 'embedding_dim', 'nodes_hidden_dense_layer', 'filepath', 'output_file', 'sentences_train', 'sentences_test', 'Y_train', 'Y_test', 'output_label'])

# %% [markdown]
# ## 3. Vectorization

# %%
if use_keras_tokenizer:
    data['X_train'], data['X_test'], data['vocab_size'], data['vocab'] = modelling.keras_tokenizer(num_words = data['num_words'], 
                                                                                         sentences_train = data['sentences_train'] , 
                                                                                         sentences_test = data['sentences_test'],
                                                                                         seq_input_len = data['seq_input_len'])
elif use_tfidf_tokenizer: # Not implemented yet
    data['X_train'], data['X_test'], data['vocab_size'], data['vocab'] = modelling.tfidf_tokenizer(num_words = data['num_words'],
                                                                                         corpus = corpus,
                                                                                         sentences_train = data['sentences_train'],
                                                                                         sentences_test = data['sentences_test'])
    
if use_tfidf_as_embedding_weights:
    
    data['embedding_matrix'], data['embedding_dim']  = modelling.tfidf_as_embedding_weights(num_words = data['num_words'], 
                                                                  corpus = corpus, 
                                                                  sentences_train = data['sentences_train'])
    
elif use_glove_pretrained_embeddings_weights:
    
    data['embedding_matrix'], data['embedding_dim'] = modelling.fit_pretrained_embedding_space_glove(embedding_dim = data['embedding_dim'], 
                                                                           filepath = data['filepath'] , 
                                                                           vocab = data['vocab'])

# %%
data.keys()
# Out:
# dict_keys(['epochs', 'batch_size', 'num_words', 'cv', 'n_iter', 'seq_input_len', 'embedding_dim', 'nodes_hidden_dense_layer', 'filepath', 'output_file', 'sentences_train', 'sentences_test', 'Y_train', 'Y_test', 'output_label', 'X_train', 'X_test', 'vocab_size', 'vocab', 'embedding_matrix'])

# %%
data['embedding_dim']
# Out:
# 40

# %%
data_pre = modelling.data_vectorization(sentences_train = data['sentences_train'], 
                       sentences_test = data['sentences_test'], 
                       num_words = data['num_words'], 
                       seq_input_len = data['seq_input_len'], 
                       filepath = data['filepath'],
                       corpus = corpus,
                       vocab = data['vocab'],
                       embedding_dim = data['embedding_dim'],
                       use_keras_tokenizer = use_keras_tokenizer, 
                       use_tfidf_tokenizer = use_tfidf_tokenizer, 
                       use_tfidf_as_embedding_weights = use_tfidf_as_embedding_weights,
                       use_glove_pretrained_embeddings_weights = use_glove_pretrained_embeddings_weights)

# Concat two dictionaries
data = {**data, **data_pre}

# %%
data.keys()
# Out:
# dict_keys(['epochs', 'batch_size', 'num_words', 'cv', 'n_iter', 'seq_input_len', 'embedding_dim', 'nodes_hidden_dense_layer', 'filepath', 'output_file', 'sentences_train', 'sentences_test', 'Y_train', 'Y_test', 'output_label', 'X_train', 'X_test', 'vocab_size', 'vocab', 'embedding_matrix'])

# %%
param_grid['embedding_matrix'] = ([data['embedding_matrix']])
param_grid['output_label'] = [data['output_label']]

# %% [markdown]
# ## 4. Hyperparameter Optimization
#
# Reference: https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %%
Y_pred = modelling.hyperparameter_optimization( 
                            X_train = data['X_train'], 
                            Y_train = data['Y_train'], 
                            X_test = data['X_test'], 
                            Y_test = data['Y_test'] , 
                            epochs = data['epochs'] , 
                            batch_size = data['batch_size'],
                            param_grid = param_grid,
                            cv = data['cv'], 
                            n_iter = data['n_iter'],
                            output_file = data['output_file'],
                            verbose = False)
# Out:
# Creating Model...
# Selecting Parameters...
# Evaluating Model...
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_21 (Embedding)     (None, 10, 40)            118720
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 8, 128)            15488
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 5, 32)             16416
# _________________________________________________________________
# global_max_pooling1d_21 (Glo (None, 32)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 150,819
# Trainable params: 32,099
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_21_input'), name='embedding_21_input', description="created by layer 'embedding_21_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_21_input'), name='embedding_21_input', description="created by layer 'embedding_21_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_21_input'), name='embedding_21_input', description="created by layer 'embedding_21_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_22 (Embedding)     (None, 10, 40)            118720
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 8, 128)            15488
# _________________________________________________________________
# conv1d_45 (Conv1D)           (None, 5, 32)             16416
# _________________________________________________________________
# global_max_pooling1d_22 (Glo (None, 32)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_45 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 150,819
# Trainable params: 32,099
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_22_input'), name='embedding_22_input', description="created by layer 'embedding_22_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_22_input'), name='embedding_22_input', description="created by layer 'embedding_22_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_22_input'), name='embedding_22_input', description="created by layer 'embedding_22_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_23 (Embedding)     (None, 10, 40)            118720
# _________________________________________________________________
# conv1d_46 (Conv1D)           (None, 8, 128)            15488
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 5, 32)             16416
# _________________________________________________________________
# global_max_pooling1d_23 (Glo (None, 32)                0
# _________________________________________________________________
# dense_46 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_47 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 150,819
# Trainable params: 32,099
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_23_input'), name='embedding_23_input', description="created by layer 'embedding_23_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_23_input'), name='embedding_23_input', description="created by layer 'embedding_23_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_23_input'), name='embedding_23_input', description="created by layer 'embedding_23_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_24 (Embedding)     (None, 10, 40)            118720
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 8, 128)            15488
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 5, 32)             16416
# _________________________________________________________________
# global_max_pooling1d_24 (Glo (None, 32)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 150,819
# Trainable params: 32,099
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_24_input'), name='embedding_24_input', description="created by layer 'embedding_24_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_24_input'), name='embedding_24_input', description="created by layer 'embedding_24_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_24_input'), name='embedding_24_input', description="created by layer 'embedding_24_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_25 (Embedding)     (None, 20, 40)            118720
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 18, 64)            7744
# _________________________________________________________________
# conv1d_51 (Conv1D)           (None, 14, 16)            5136
# _________________________________________________________________
# global_max_pooling1d_25 (Glo (None, 16)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 15)                255
# _________________________________________________________________
# dense_51 (Dense)             (None, 5)                 80
# =================================================================
# Total params: 131,935
# Trainable params: 13,215
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_25_input'), name='embedding_25_input', description="created by layer 'embedding_25_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_25_input'), name='embedding_25_input', description="created by layer 'embedding_25_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_25_input'), name='embedding_25_input', description="created by layer 'embedding_25_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_26 (Embedding)     (None, 20, 40)            118720
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 18, 64)            7744
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 14, 16)            5136
# _________________________________________________________________
# global_max_pooling1d_26 (Glo (None, 16)                0
# _________________________________________________________________
# dense_52 (Dense)             (None, 15)                255
# _________________________________________________________________
# dense_53 (Dense)             (None, 5)                 80
# =================================================================
# Total params: 131,935
# Trainable params: 13,215
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_26_input'), name='embedding_26_input', description="created by layer 'embedding_26_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_26_input'), name='embedding_26_input', description="created by layer 'embedding_26_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_26_input'), name='embedding_26_input', description="created by layer 'embedding_26_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_27 (Embedding)     (None, 20, 40)            118720
# _________________________________________________________________
# conv1d_54 (Conv1D)           (None, 18, 64)            7744
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 14, 16)            5136
# _________________________________________________________________
# global_max_pooling1d_27 (Glo (None, 16)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 15)                255
# _________________________________________________________________
# dense_55 (Dense)             (None, 5)                 80
# =================================================================
# Total params: 131,935
# Trainable params: 13,215
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_27_input'), name='embedding_27_input', description="created by layer 'embedding_27_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_27_input'), name='embedding_27_input', description="created by layer 'embedding_27_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_27_input'), name='embedding_27_input', description="created by layer 'embedding_27_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_28 (Embedding)     (None, 20, 40)            118720
# _________________________________________________________________
# conv1d_56 (Conv1D)           (None, 18, 64)            7744
# _________________________________________________________________
# conv1d_57 (Conv1D)           (None, 14, 16)            5136
# _________________________________________________________________
# global_max_pooling1d_28 (Glo (None, 16)                0
# _________________________________________________________________
# dense_56 (Dense)             (None, 15)                255
# _________________________________________________________________
# dense_57 (Dense)             (None, 5)                 80
# =================================================================
# Total params: 131,935
# Trainable params: 13,215
# Non-trainable params: 118,720
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_28_input'), name='embedding_28_input', description="created by layer 'embedding_28_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_28_input'), name='embedding_28_input', description="created by layer 'embedding_28_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_28_input'), name='embedding_28_input', description="created by layer 'embedding_28_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_29 (Embedding)     (None, 40, 40)            118720
# _________________________________________________________________
# conv1d_58 (Conv1D)           (None, 39, 256)           20736
# _________________________________________________________________
# conv1d_59 (Conv1D)           (None, 37, 64)            49216
# _________________________________________________________________
# global_max_pooling1d_29 (Glo (None, 64)                0
# _________________________________________________________________
# dense_58 (Dense)             (None, 5)                 325
# _________________________________________________________________
# dense_59 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 189,027
# Trainable params: 70,307
# Non-trainable params: 118,720
# _________________________________________________________________
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_30 (Embedding)     (None, 40, 40)            118720
# _________________________________________________________________
# conv1d_60 (Conv1D)           (None, 39, 256)           20736
# _________________________________________________________________
# conv1d_61 (Conv1D)           (None, 37, 64)            49216
# _________________________________________________________________
# global_max_pooling1d_30 (Glo (None, 64)                0
# _________________________________________________________________
# dense_60 (Dense)             (None, 5)                 325
# _________________________________________________________________
# dense_61 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 189,027
# Trainable params: 70,307
# Non-trainable params: 118,720
# _________________________________________________________________
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_31 (Embedding)     (None, 40, 40)            118720
# _________________________________________________________________
# conv1d_62 (Conv1D)           (None, 39, 256)           20736
# _________________________________________________________________
# conv1d_63 (Conv1D)           (None, 37, 64)            49216
# _________________________________________________________________
# global_max_pooling1d_31 (Glo (None, 64)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 5)                 325
# _________________________________________________________________
# dense_63 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 189,027
# Trainable params: 70,307
# Non-trainable params: 118,720
# _________________________________________________________________
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_32 (Embedding)     (None, 40, 40)            118720
# _________________________________________________________________
# conv1d_64 (Conv1D)           (None, 39, 256)           20736
# _________________________________________________________________
# conv1d_65 (Conv1D)           (None, 37, 64)            49216
# _________________________________________________________________
# global_max_pooling1d_32 (Glo (None, 64)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 5)                 325
# _________________________________________________________________
# dense_65 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 189,027
# Trainable params: 70,307
# Non-trainable params: 118,720
# _________________________________________________________________
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_33 (Embedding)     (None, 10, 30)            180000
# _________________________________________________________________
# conv1d_66 (Conv1D)           (None, 8, 128)            11648
# _________________________________________________________________
# conv1d_67 (Conv1D)           (None, 4, 32)             20512
# _________________________________________________________________
# global_max_pooling1d_33 (Glo (None, 32)                0
# _________________________________________________________________
# dense_66 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_67 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 212,355
# Trainable params: 212,355
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_33_input'), name='embedding_33_input', description="created by layer 'embedding_33_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_33_input'), name='embedding_33_input', description="created by layer 'embedding_33_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_33_input'), name='embedding_33_input', description="created by layer 'embedding_33_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_34 (Embedding)     (None, 10, 30)            180000
# _________________________________________________________________
# conv1d_68 (Conv1D)           (None, 8, 128)            11648
# _________________________________________________________________
# conv1d_69 (Conv1D)           (None, 4, 32)             20512
# _________________________________________________________________
# global_max_pooling1d_34 (Glo (None, 32)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_69 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 212,355
# Trainable params: 212,355
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_34_input'), name='embedding_34_input', description="created by layer 'embedding_34_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_34_input'), name='embedding_34_input', description="created by layer 'embedding_34_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_34_input'), name='embedding_34_input', description="created by layer 'embedding_34_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_35 (Embedding)     (None, 10, 30)            180000
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 8, 128)            11648
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 4, 32)             20512
# _________________________________________________________________
# global_max_pooling1d_35 (Glo (None, 32)                0
# _________________________________________________________________
# dense_70 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_71 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 212,355
# Trainable params: 212,355
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_35_input'), name='embedding_35_input', description="created by layer 'embedding_35_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_35_input'), name='embedding_35_input', description="created by layer 'embedding_35_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_35_input'), name='embedding_35_input', description="created by layer 'embedding_35_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_36 (Embedding)     (None, 10, 30)            180000
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 8, 128)            11648
# _________________________________________________________________
# conv1d_73 (Conv1D)           (None, 4, 32)             20512
# _________________________________________________________________
# global_max_pooling1d_36 (Glo (None, 32)                0
# _________________________________________________________________
# dense_72 (Dense)             (None, 5)                 165
# _________________________________________________________________
# dense_73 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 212,355
# Trainable params: 212,355
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_36_input'), name='embedding_36_input', description="created by layer 'embedding_36_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_36_input'), name='embedding_36_input', description="created by layer 'embedding_36_input'"), but it was called on an input with incompatible shape (None, 40).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name='embedding_36_input'), name='embedding_36_input', description="created by layer 'embedding_36_input'"), but it was called on an input with incompatible shape (None, 40).
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_37 (Embedding)     (None, 40, 50)            250000
# _________________________________________________________________
# conv1d_74 (Conv1D)           (None, 39, 64)            6464
# _________________________________________________________________
# conv1d_75 (Conv1D)           (None, 36, 16)            4112
# _________________________________________________________________
# global_max_pooling1d_37 (Glo (None, 16)                0
# _________________________________________________________________
# dense_74 (Dense)             (None, 40)                680
# _________________________________________________________________
# dense_75 (Dense)             (None, 5)                 205
# =================================================================
# Total params: 261,461
# Trainable params: 261,461
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_38 (Embedding)     (None, 40, 50)            250000
# _________________________________________________________________
# conv1d_76 (Conv1D)           (None, 39, 64)            6464
# _________________________________________________________________
# conv1d_77 (Conv1D)           (None, 36, 16)            4112
# _________________________________________________________________
# global_max_pooling1d_38 (Glo (None, 16)                0
# _________________________________________________________________
# dense_76 (Dense)             (None, 40)                680
# _________________________________________________________________
# dense_77 (Dense)             (None, 5)                 205
# =================================================================
# Total params: 261,461
# Trainable params: 261,461
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_39 (Embedding)     (None, 40, 50)            250000
# _________________________________________________________________
# conv1d_78 (Conv1D)           (None, 39, 64)            6464
# _________________________________________________________________
# conv1d_79 (Conv1D)           (None, 36, 16)            4112
# _________________________________________________________________
# global_max_pooling1d_39 (Glo (None, 16)                0
# _________________________________________________________________
# dense_78 (Dense)             (None, 40)                680
# _________________________________________________________________
# dense_79 (Dense)             (None, 5)                 205
# =================================================================
# Total params: 261,461
# Trainable params: 261,461
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_40 (Embedding)     (None, 40, 50)            250000
# _________________________________________________________________
# conv1d_80 (Conv1D)           (None, 39, 64)            6464
# _________________________________________________________________
# conv1d_81 (Conv1D)           (None, 36, 16)            4112
# _________________________________________________________________
# global_max_pooling1d_40 (Glo (None, 16)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 40)                680
# _________________________________________________________________
# dense_81 (Dense)             (None, 5)                 205
# =================================================================
# Total params: 261,461
# Trainable params: 261,461
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_41 (Embedding)     (None, 40, 40)            118720
# _________________________________________________________________
# conv1d_82 (Conv1D)           (None, 39, 256)           20736
# _________________________________________________________________
# conv1d_83 (Conv1D)           (None, 37, 64)            49216
# _________________________________________________________________
# global_max_pooling1d_41 (Glo (None, 64)                0
# _________________________________________________________________
# dense_82 (Dense)             (None, 5)                 325
# _________________________________________________________________
# dense_83 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 189,027
# Trainable params: 70,307
# Non-trainable params: 118,720
# _________________________________________________________________
# c:\users\user\anaconda3\envs\class\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#  label accuracy could not be calculated
# Writting results...
# Running CNN Modeling data set
# Best Accuracy : 0.7736
# {'vocab_size': 5000, 'use_pretrained_embeddings': True, 'seq_input_len': 40, 'output_label': 5, 'num_filters_cv': (256, 64), 'nodes_hidden_dense_layer': 5, 'kernel_size_cv': (2, 3), 'embedding_matrix': array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.14896999, -0.41446   ,  0.57534999, ...,  0.025145  ,
#          0.32242   , -0.053632  ],
#        [ 0.54816997, -0.2086    ,  1.06239998, ...,  0.33985001,
#          0.36284   ,  0.30858001],
#        ...,
#        [-0.16616   , -0.52687001,  0.083531  , ...,  0.25391001,
#         -1.02269995, -1.21860003],
#        [ 1.34249997,  0.76612997, -0.84473002, ..., -0.13552999,
#         -0.031774  , -0.26947001],
#        [-0.038405  , -0.28863999,  0.032145  , ..., -0.2325    ,
#          0.24162   ,  0.026598  ]]), 'embedding_dim': 50}
# Test Accuracy : 0.8610

# %% [markdown]
# ## 5. Score Analysis

# %%
# Generate Confusion Matrix
conf_matrix = confusion_matrix(Y_pred, data['Y_test'].argmax(axis=1)) / len(Y_pred)

# Calculate Label Accuracy
label_acc = postprocessing.cal_label_accuracy(conf_matrix, verbose  = 1)
# Out:
# Accuracy for label 0 :  90.41  %
# Accuracy for label 1 :  60.0  %
# Accuracy for label 2 :  57.14  %
# Accuracy for label 3 :  45.45  %
# Accuracy for label 4 :  58.06  %
